# %%
t24_values_=['CC69718O0630M60459', ['02', '21', '86', '03', '22', '97', 'HYD', 'cb', 'fgjnb', 'qaZzp', 'qwq', '1C', '00', 'jkh', 'q', 'a', 'sdf', 'fdgsd', 'reter'], ['12', '20', '87', '04', '23', '98', 'VSK', 'vb', 'vbmnvbnm', 'WwSxO', 'ews', '2C', '00', 'mn,', 'WwW', 'b', 'dfd', 'vcbcb', 'cevbec'], ['11', '— 19', '88', '— 05 ', '24', '99', 'SEC', 'CV', 'vagyujmnb', 'edCc', 'sdsd', '3C', '00', 'hjk', 'e', 'Xx', 'dfd', 'Crwere', 'r'], ['18', '89', '06', '25', '00', 'BZA', 'bv', 'vnbmnvghj', 'r', 'fVvCXXC', '40', '00', 'nm.', 'Zz', 'CVCV', 'Zz', 'vcbcvb', '10', 'vcbcvb'], ['09', '17', '90', '07', '26', '01', 'ONG', 'vb', 'gyuybnmbm', 't9.y', 'dfdf', '50', '00', 'nm.', 't', 'JC', 'CVC', 'rery', 'gfhf'], ['08', '16', '91', '08', '27', '02', 'XYZ', 'vc', 'bnmujhbm', 'VYhNnot', ' XCVXCV', '6/7', '00', '', 'u', 'y', 'XCCV', 'vvnvb', 'Khikhk']]

t24_confs_=['CC69718O0630M60459', ['89', '95', '96', '96', '96', '96', '96', '96', '91', '80', '84', '92', '92', '83', '81', '94', '96', '92', '89'], ['96', '96', '96', '96', '96', '96', '91', '95', '66', '71', '95', '90', '89', '83', '54', '93', '92', '87', '46'], ['83', '52', '96', '45', '95', '96', '96', '94', '29', '57', '92', '91', '64', '88', '59', '61', '93', '36', '69'], ['96', '96', '96', '93', '96', '96', '96', '68', '76', '55', '96', '84', '87', '55', '91', '55', '86', '96', '89'], ['84', '96', '96', '91', '96', '96', '95', '95', '69', '49', '91', '96', '95', '72', '92', '30', '76', '89', '89'], ['96', '96', '93', '95', '73', '79', '94', '71', '91', '29', '19', '80', '48', '0', '53', '93', '90', '51', '52']]

for i in range(1,len(t24_values_)):
        t24_values_insert = []
        
        t24_confs_insert = []
        
        t24_values_insert.append(t24_values_[0])
        t24_values_insert.append(i)
        t24_values_insert += t24_values_[i]
        
        t24_confs_insert.append(t24_confs_[0])
        t24_confs_insert.append(i)
        t24_confs_insert += t24_confs_[i]
        
        print(t24_values_insert)
        print(len(t24_values_insert))
        
        print(t24_confs_insert)
        print(len(t24_confs_insert))
# Out:
# ['CC69718O0630M60459', 1, '02', '21', '86', '03', '22', '97', 'HYD', 'cb', 'fgjnb', 'qaZzp', 'qwq', '1C', '00', 'jkh', 'q', 'a', 'sdf', 'fdgsd', 'reter']
# 21
# ['CC69718O0630M60459', 1, '89', '95', '96', '96', '96', '96', '96', '96', '91', '80', '84', '92', '92', '83', '81', '94', '96', '92', '89']
# 21
# ['CC69718O0630M60459', 2, '12', '20', '87', '04', '23', '98', 'VSK', 'vb', 'vbmnvbnm', 'WwSxO', 'ews', '2C', '00', 'mn,', 'WwW', 'b', 'dfd', 'vcbcb', 'cevbec']
# 21
# ['CC69718O0630M60459', 2, '96', '96', '96', '96', '96', '96', '91', '95', '66', '71', '95', '90', '89', '83', '54', '93', '92', '87', '46']
# 21
# ['CC69718O0630M60459', 3, '11', '— 19', '88', '— 05 ', '24', '99', 'SEC', 'CV', 'vagyujmnb', 'edCc', 'sdsd', '3C', '00', 'hjk', 'e', 'Xx', 'dfd', 'Crwere', 'r']
# 21
# ['CC69718O0630M60459', 3, '83', '52', '96', '45', '95', '96', '96', '94', '29', '57', '92', '91', '64', '88', '59', '61', '93', '36', '69']
# 21
# ...
